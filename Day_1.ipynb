# %% [markdown]
# Module is a file containing the code written by someone else which we can use in our code.
# pip is the package manager that is used to install modules.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Q1. Print a poem.
#
# To print multiple single lines in a single print command, we enclose them between triple single quotes.

# %%
print('''How easily happiness begins by   
dicing onions. A lump of sweet butter   
slithers and swirls across the floor   
of the sauté pan, especially if its   
errant path crosses a tiny slick
of olive oil. Then a tumble of onions.

This could mean soup or risotto   
or chutney (from the Sanskrit
chatni, to lick). Slowly the onions   
go limp and then nacreous
and then what cookbooks call clear,   
though if they were eyes you could see
''')
# Out:
# How easily happiness begins by
# dicing onions. A lump of sweet butter
# slithers and swirls across the floor
# of the sauté pan, especially if its
# errant path crosses a tiny slick
# of olive oil. Then a tumble of onions.
#
# This could mean soup or risotto
# or chutney (from the Sanskrit
# chatni, to lick). Slowly the onions
# go limp and then nacreous
# and then what cookbooks call clear,
# though if they were eyes you could see

# %% [markdown]
# Q.2 Print a table of 5 using REPL.
#
#
# So REPL is basically the script mode of python

# %% [markdown]
# Q3. Use a python module and write a program of your choice.

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("So today I will be reading a poem about onions. How easily happiness begins by dicing onions. A lump of sweet butter slithers and swirls across the floor of the sauté pan, especially if its errant path crosses a tiny slick of olive oil. Then a tumble of onions. This could mean soup or risotto or chutney from the Sanskrit chatni, to lick. Slowly the onions go limp and then nacreous and then what cookbooks call clear, though if they were eyes you could see.")
engine.runAndWait()

# %% [markdown]
# Q4. Write a Python program to print the contents of a directory using the os module. Search online for the function which does that.

# %%
import os

path = "C:\\Users\\sanch\\Documents"

contents = os.listdir(path)

for item in contents:
    print(item)
# Out:
# Custom Office Templates
# desktop.ini
# Docs
# EAadhaar_1171034240175720110911130640_0705202601325.pdf
# IMG_20260105_211651.jpg
# IMG_20260529_185213.jpg
# in.gov.abc-ABCID-211904182724.pdf
# My Music
# My Pictures
# My Videos
# New folder
# OneNote Notebooks
# Power BI Desktop
# TallyODBC64_9000.dsn
# Untitled design.png
# WhatsApp Image 2026-05-06 at 11.56.53 PM.jpeg
# WhatsApp Image 2026-05-07 at 7.58.37 PM.jpeg
